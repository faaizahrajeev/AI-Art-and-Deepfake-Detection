# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/kaggle/input/cutmix-17march/cutmix_new/train'
test_dir = '/kaggle/input/cutmix-17march/cutmix_new/test'

img_height = 224
img_width = 224
batch_size = 32

preprocess_input = tf.keras.applications.densenet.preprocess_input

train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')

densenet_base = DenseNet121(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

for layer in densenet_base.layers:
    layer.trainable = False

x = layers.GlobalAveragePooling2D()(densenet_base.output)
x = layers.Dense(256, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(inputs=densenet_base.input, outputs=output)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,
                    steps_per_epoch=None,  # Set to None to run until the generator stops
                    epochs=10,
                    validation_data=test_generator,
                    validation_steps=None)  # Set to None to run until the generator stops

loss, accuracy = model.evaluate(test_generator)
print("Test Accuracy:", accuracy)
# Out:
# 2024-03-17 22:12:33.201874: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-17 22:12:33.202042: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-17 22:12:33.377778: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 1294 images belonging to 2 classes.
# Found 856 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 275s 6s/step - accuracy: 0.6433 - loss: 0.7074 - val_accuracy: 0.8061 - val_loss: 0.4200
# Epoch 2/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 243s 6s/step - accuracy: 0.8406 - loss: 0.3833 - val_accuracy: 0.8014 - val_loss: 0.4179
# Epoch 3/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 242s 6s/step - accuracy: 0.8357 - loss: 0.3734 - val_accuracy: 0.8762 - val_loss: 0.3016
# Epoch 4/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 242s 6s/step - accuracy: 0.8961 - loss: 0.2661 - val_accuracy: 0.8516 - val_loss: 0.3247
# Epoch 5/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 256s 5s/step - accuracy: 0.8981 - loss: 0.2347 - val_accuracy: 0.8995 - val_loss: 0.2733
# Epoch 6/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 269s 6s/step - accuracy: 0.9047 - loss: 0.2527 - val_accuracy: 0.8984 - val_loss: 0.2719
# Epoch 7/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 243s 6s/step - accuracy: 0.9137 - loss: 0.2220 - val_accuracy: 0.8995 - val_loss: 0.2669
# Epoch 8/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 265s 6s/step - accuracy: 0.9408 - loss: 0.1703 - val_accuracy: 0.9100 - val_loss: 0.2537
# Epoch 9/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 244s 6s/step - accuracy: 0.9545 - loss: 0.1452 - val_accuracy: 0.9019 - val_loss: 0.2739
# Epoch 10/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 257s 6s/step - accuracy: 0.9506 - loss: 0.1336 - val_accuracy: 0.8972 - val_loss: 0.2879
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.8894 - loss: 0.2677
# Test Accuracy: 0.8971962332725525
